# %%
# Daily challenge GOLD : Happy birthday

from datetime import datetime # Import the datetime class

def display_cake(candles):
    candle_part = "_" * (5 - candles) + "i" * candles + "_" * (5 - candles)
    if candles > 5:  # Handle cases where we might have more than 5 candles
        candle_part = "i" * candles
        candle_part = "_" + candle_part + "_"

    print(f"       ___{candle_part}___")
    print("      |:H:a:p:p:y:|")
    print("    __|___________|__")
    print("   |^^^^^^^^^^^^^^^^^|")
    print("   |:B:i:r:t:h:d:a:y:|")
    print("   |                 |")
    print("   ~~~~~~~~~~~~~~~~~~~")

# Ask for birthdate
birthdate_str = input("Please enter your birthdate (format: DD/MM/YYYY): ")
try:
    birth_date = datetime.strptime(birthdate_str, "%d/%m/%Y")
except ValueError:
    print("Invalid date format. Please use DD/MM/YYYY.")
    exit()

# Calculate age and candles
# Note: The functions get_age and is_leap_year are not defined in this cell.
# You will need to add those functions to make the code fully runnable.
# age = get_age(birth_date)
# last_digit = age % 10
# candles = last_digit if last_digit != 0 else 10  # If age ends with 0, use 10 candles

# Display cake(s)
# if is_leap_year(birth_date.year):
#     # Display two cakes for leap year
#     display_cake(candles)
#     display_cake(candles)
# else:
#     display_cake(candles)

# For demonstration purposes, let's display a cake with a fixed number of candles
display_cake(5)
# Out:
# Please enter your birthdate (format: DD/MM/YYYY): 26/08/1988
#        ___iiiii___
#       |:H:a:p:p:y:|
#     __|___________|__
#    |^^^^^^^^^^^^^^^^^|
#    |:B:i:r:t:h:d:a:y:|
#    |                 |
#    ~~~~~~~~~~~~~~~~~~~
