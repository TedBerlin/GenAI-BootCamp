# %% [markdown]
# Daily Challenge: Exploring the World Happiness Report with Matplotlib

# %%
import pandas as pd

# Charger le fichier CSV
df_2019 = pd.read_csv("2019.csv")

# Aperçu du jeu de données
print(df.head())

print("\nℹ️ Dataset information:")
print(df.info())

print("\nDescriptive statistics:")
print(df.describe())

print("\nAvailable columns list:")
print(df.columns)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# Vérifier les valeurs manquantes
print(df_2019.isnull().sum())

# Supprimer ou imputer les valeurs manquantes si nécessaire
df_2019 = df_2019.dropna()

# Vérifier les types de données
print(df_2019.dtypes)
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
# Social Support and Happiness
# Objectif : Visualiser la relation entre le soutien social et le score de bonheur.

import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(df_2019['Social support'], df_2019['Score'], alpha=0.7, color='teal')
plt.title('Social Support vs Happiness Score (2019)', fontsize=14)
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.show()
